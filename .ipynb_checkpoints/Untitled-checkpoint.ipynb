# %%
import pandas as pd 

train = pd.read_csv("Untitled spreadsheet - Sheet1.csv")
valid = pd.read_csv("Untitled spreadsheet - Sheet2.csv")

# getting an overview of the dataset here

print("Length of training set: ", len(train), " and shape: ", train.shape)

print("First 5 rows: ")
train.head()
# Out:
# Length of training set:  3700  and shape:  (3700, 22)
# First 5 rows:
#   variable1  variable2  variable3 variable4 variable5 variable6 variable7  \
# 0         a       17.0       92.0         5  4.00E-05         u         g
# 1         b       16.0       92.0         3   0.00035         y         p
# 2         b       31.0       25.0         0      1125         u         g
# 3         a       48.0       17.0         0      1335         u         g
# 4         b       32.0       33.0         0        35         u         g
#
#   variable8 variable9 variable10  ... variable13 variable14 variable15  \
# 0         c         v          1  ...          t          1          t
# 1         k         v          0  ...          f          0          f
# 2        ff        ff          0  ...          1          f          g
# 3         i         o          0  ...          f          0          f
# 4         k         v          0  ...          f          0          t
#
# ...

# %%
import numpy as np

train.describe(include=np.object)
# Out:
#        variable1 variable4 variable5 variable6 variable7 variable8 variable9  \
# count       3661      3700      3636      3636      3636      3634      3698
# unique         2        49       148        16        19        28        29
# top            b         0         u         u         g         c         v
# freq        2382      2364       700      2255      2255       586      1543
#
#        variable10 variable11 variable12 variable13 variable14 variable15  \
# count        3700       3700       3700       3700       3700       3635
# unique         36         28         10         23         26         36
# top             0          t          t          t          0          g
# freq          840       1320       2557       1426        755       1259
#
#        variable17 variable18 variable19 classLabel Unnamed: 19 Unnamed: 20  \
# count        3698       3585       3502       2935        2450        3345
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3700 entries, 0 to 3699
# Data columns (total 22 columns):
# variable1      3661 non-null object
# variable2      3661 non-null float64
# variable3      3700 non-null float64
# variable4      3700 non-null object
# variable5      3636 non-null object
# variable6      3636 non-null object
# variable7      3636 non-null object
# variable8      3634 non-null object
# variable9      3698 non-null object
# variable10     3700 non-null object
# variable11     3700 non-null object
# variable12     3700 non-null object
# variable13     3700 non-null object
# variable14     3700 non-null object
# variable15     3635 non-null object
# variable17     3698 non-null object
# variable18     3585 non-null object
# variable19     3502 non-null object
# classLabel     2935 non-null object
# Unnamed: 19    2450 non-null object
# Unnamed: 20    3345 non-null object
# Unnamed: 21    2009 non-null object
# dtypes: float64(2), object(20)
# ...

# %%
train_without_missing_data = train.dropna()
train_without_missing_data.shape
# Out:
# (789, 22)

# %%
train_deleted = train.drop(columns = ['Unnamed: 19'])
valid_deleted = valid.drop(columns = ['Unnamed: 19'])

# %%
train_deleted.shape
# Out:
# (3700, 21)

# %%
train_deleted.head()
# Out:
#   variable1  variable2  variable3 variable4 variable5 variable6 variable7  \
# 0         a       17.0       92.0         5  4.00E-05         u         g
# 1         b       16.0       92.0         3   0.00035         y         p
# 2         b       31.0       25.0         0      1125         u         g
# 3         a       48.0       17.0         0      1335         u         g
# 4         b       32.0       33.0         0        35         u         g
#
#   variable8 variable9 variable10  ... variable12 variable13 variable14  \
# 0         c         v          1  ...          f          t          1
# 1         k         v          0  ...          f          f          0
# 2        ff        ff          0  ...          t          1          f
# 3         i         o          0  ...          f          f          0
# 4         k         v          0  ...          f          f          0
#
#   variable15 variable17 variable18 variable19 classLabel Unnamed: 20  \
# ...

# %%
train_deleted["Unnamed: 20"].replace({"yes.":1, "no.":0}, inplace = True)
valid_deleted["Unnamed: 20"].replace({"yes.":1, "no.":0}, inplace = True)
train_deleted["Unnamed: 21"].replace({"yes.":1, "no.":0}, inplace = True)
train_deleted
# Out:
#      variable1  variable2  variable3 variable4 variable5 variable6 variable7  \
# 0            a       17.0    92.0000         5  4.00E-05         u         g
# 1            b       16.0    92.0000         3   0.00035         y         p
# 2            b       31.0    25.0000         0      1125         u         g
# 3            a       48.0    17.0000         0      1335         u         g
# 4            b       32.0    33.0000         0        35         u         g
# 5            a       34.0    83.0000         0       125         y         p
# 6            a       26.0    17.0000    0.0002         u         g         j
# 7            b       21.0    17.0000         8   0.00075         y         p
# 8            b       28.0    92.0000         3   0.00075         u         g
# 9            b       18.0    17.0000         0      1025         u         g
# 10           a       24.0    75.0000         0     13665         u         g
# ...

# %%
train_deleted = train_deleted.drop(columns = ['Unnamed: 21'])
valid_deleted = valid_deleted.drop(columns = ['Unnamed: 21'])

# %%
train_deleted.head()
# Out:
#   variable1  variable2  variable3 variable4 variable5 variable6 variable7  \
# 0         a       17.0       92.0         5  4.00E-05         u         g
# 1         b       16.0       92.0         3   0.00035         y         p
# 2         b       31.0       25.0         0      1125         u         g
# 3         a       48.0       17.0         0      1335         u         g
# 4         b       32.0       33.0         0        35         u         g
#
#   variable8 variable9 variable10 variable11 variable12 variable13 variable14  \
# 0         c         v          1         75          f          t          1
# 1         k         v          0         29          f          f          0
# 2        ff        ff          0          f          t          1          f
# 3         i         o          0        335          f          f          0
# 4         k         v          0          5          f          f          0
#
# ...

# %%
train_deleted.dropna(subset = ["Unnamed: 20"], inplace=True)
valid_deleted.dropna(subset = ["Unnamed: 20"], inplace=True)
train_deleted.shape
train_deleted
# Out:
#      variable1  variable2  variable3 variable4 variable5 variable6 variable7  \
# 0            a       17.0       92.0         5  4.00E-05         u         g
# 1            b       16.0       92.0         3   0.00035         y         p
# 2            b       31.0       25.0         0      1125         u         g
# 3            a       48.0       17.0         0      1335         u         g
# 4            b       32.0       33.0         0        35         u         g
# 5            a       34.0       83.0         0       125         y         p
# 7            b       21.0       17.0         8   0.00075         y         p
# 8            b       28.0       92.0         3   0.00075         u         g
# 9            b       18.0       17.0         0      1025         u         g
# 10           a       24.0       75.0         0     13665         u         g
# 12           a       18.0       17.0         0         1         y         p
# ...

# %%
train_deleted = train_deleted.drop(columns = ['classLabel'])
valid_deleted = valid_deleted.drop(columns = ['classLabel'])

# %%
valid_deleted
# Out:
#     variable1  variable2  variable3 variable4 variable5 variable6 variable7  \
# 0           b       32.0       33.0         0        75         u         g
# 1           b       23.0       58.0         0       179         u         g
# 2           b       36.0       42.0         7  5.00E-05         y         p
# 3           b       18.0       42.0         0     10415         y         p
# 4           b       24.0        5.0         0     13335         y         p
# 6           b       23.0       42.0    0.0001         u         g         c
# 7           b       29.0       58.0         0       475         u         g
# 8           b       27.0       42.0         0       125         u         g
# 9           b       58.0       58.0         0       271         u         g
# 10          b       19.0        5.0         0      9585         u         g
# 11          b       44.0       25.0         0        11         y         p
# ...

# %%
valid.shape
# Out:
# (200, 22)

# %%
# from sklearn import preprocessing
# le = preprocessing.LabelEncoder()
# for i in range(17):
#     train_deleted[:,i] = le.fit_transform(train_deleted[:,i])
# train_deleted
    
    
    
    
print(train_deleted.shape)
    
    
x = train_deleted[train_deleted.columns[1:3]]
y = train_deleted['Unnamed: 20']


x_test = valid_deleted[train_deleted.columns[1:3]]
y_test = valid_deleted['Unnamed: 20']


from sklearn.ensemble import RandomForestClassifier



clf = RandomForestClassifier(max_depth=2, random_state=0)
clf.fit(x,y)
y_pred_ts=clf.predict(X_test)

print("=== Confusion Matrix ===")
print(confusion_matrix(y_test, y_pred_ts))
# Out:
# (3345, 19)
# /home/ahmed/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-77-b277521bdc55> in <module>
#      24
#      25 clf = RandomForestClassifier(max_depth=2, random_state=0)
# ---> 26 clf.fit(x,y)
#      27 y_pred_ts=clf.predict(X_test)
#      28
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py in fit(self, X, y, sample_weight)
#     248
#     249         # Validate or convert input data
# --> 250         X = check_array(X, accept_sparse="csc", dtype=DTYPE)
#     251         y = check_array(y, accept_sparse='csc', ensure_2d=False, dtype=None)
#     252         if sample_weight is not None:
#
# ...
